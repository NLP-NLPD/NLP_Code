# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/UpstageAI/cookbook/blob/main/cookbooks/upstage/Solar-Full-Stack LLM-101/05_3_OracleDB.ipynb">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import wikipediaapi
import re

def detect_language(text):
    """
    Detect whether the text is in Korean or English.
    """
    if re.search(r'[가-힣]', text):
        return 'ko' 
    else:
        return 'en' 

def extract_core_question(question, core_extraction_model):
    """
    Use LLM to extract the core part of the question, with prompts in the appropriate language.
    """
    language = detect_language(question)
    
    if language == 'ko':
        prompt = f"다음 질문에서 핵심 내용을 추출하세요 (선택지 제외):\n\n{question}\n\n핵심 내용:"
    elif language == 'en':
        prompt = f"Extract the core part of the following question (exclude choices):\n\n{question}\n\nCore content:"
    else:
        raise ValueError("Unsupported language detected.")
    core = core_extraction_model(prompt)
    return core.strip()

def initialize_wikipedia(language):
    """
    Initialize Wikipedia API object with the specified language.
    """
    return wikipediaapi.Wikipedia(
        language=language,
        user_agent='NLP_Team/1.0 (ewhanthbeot@ewhain.net)' 
    )

def fetch_from_wikipedia(query):
    """
    Fetch a summary from Wikipedia based on the query's language.
    """
    language = detect_language(query) 
    wiki_api = initialize_wikipedia(language) 
    
    page = wiki_api.page(query)
    if page.exists():
        return page.summary[:500] 
    else:
        return f"Wikipedia에서 관련 정보를 찾을 수 없습니다 (언어: {language})."

# %%
def normalize_answer(answer):
    """
    Normalize the format of the answer to handle cases like 'A' vs '(A)'.
    """
    if answer.startswith("(") and answer.endswith(")"):
        return answer[1:-1]  # Remove surrounding parentheses
    return answer.strip()  # Remove any extra whitespace

# %%
correct = 0

for i, question in enumerate(prompts):
    core_question = extract_core_question(question, qa_chain["llm"])
    print(f"질문 핵심 추출: {core_question}")
    
    context = retrieve_context(core_question, list_kb)
    
    if not context.strip():
        print(f"PDF에서 관련 정보를 찾을 수 없습니다. Wikipedia를 검색합니다.")
        context = fetch_from_wikipedia(core_question)
    
    if not context.strip():
        print("PDF 및 Wikipedia 모두에서 관련 정보를 찾을 수 없습니다.")
        context = "No relevant information found."

    prompt = qa_chain["prompt"].format(context=context, question=question)
    
    result = qa_chain["llm"](prompt)
    predicted_answer = extract_answer(result)
    
    if predicted_answer == "N/A":
        print(f"답변이 N/A로 표시됨: 다시 확인 중...")
        prompt_with_choices = f"다음 선택지 중에서 정답을 선택하세요:\n{question}"
        result = qa_chain["llm"](prompt_with_choices)
        predicted_answer = extract_answer(result)

    normalized_predicted = normalize_answer(predicted_answer)
    normalized_actual = normalize_answer(answers[i])
    
    print(f"질문 {i + 1}: {question}")
    print(f"생성된 답변: {result}")
    print(f"예상 답: {normalized_predicted}, 실제 답: {normalized_actual}\n")
    
    if normalized_predicted == normalized_actual:
        correct += 1
# Out:
# 질문 핵심 추출: 건축학전공의 수업연한은 5년입니다.
# 질문 1: QUESTION1) 건축학전공의 수업연한은?
# (A) 4년
# (B) 5년
# (C) 6년
# (D) 7년
# 생성된 답변: (C) 6년
# 예상 답: C, 실제 답: B
#
# 질문 핵심 추출: 학사경고를 받는 학점은 1.8입니다.
# 질문 2: QUESTION2) 학사경고를 받는 학점은?
# (A) 1.6
# (B) 1.8
# (C) 2.0
# (D) 2.2
# 생성된 답변: (C) 2.0
# 예상 답: C, 실제 답: A
#
# 질문 핵심 추출: 계절학기 취득 가능 학점은.
# 질문 3: QUESTION3) 계절학기 취득 가능 학점은?
# (A) 2학점
# (B) 4학점
# (C) 6학점
# (D) 8학점
# 생성된 답변: (C) 6학점
# 예상 답: C, 실제 답: C
#
# 질문 핵심 추출: 중앙행정기관이 아닌 기관은 교무처입니다.
# 답변이 N/A로 표시됨: 다시 확인 중...
# 질문 4: QUESTION4) 중앙행정기관이 아닌 기관은?
# (A) 교무처
# (B) 인재개발처
# (C) 학생처
# (D) 총무처
# 생성된 답변: 정답은 (A) 교무처입니다. 중앙행정기관은 일반적으로 정부 조직 내에서 주요 업무를 담당하는 기관을 의미합니다. (B) 인재개발처, (C) 학생처, (D) 총무처는 교육 기관 내의 주요 행정 기능을 수행하는 부서로 볼 수 있습니다. 반면, (A) 교무처는 주로 학사 행정과 교육 관련 업무를 담당하는 부서로, 중앙행정기관으로는 분류되지 않습니다.
# 예상 답: A, 실제 답: B
#
# 질문 핵심 추출: 체육특기자의 대회출전 및 훈련으로 인한 출석대체인정은 1학기 수업시간의 6분의 1 이내로 한다.
# 질문 5: QUESTION5) 체육특기자의 대회출전 및 훈련으로 인한 출석대체인정은 1학기 수업시간의 ___ 이내로 한다.
# (A) 8분의 1
# (B) 6분의 1
# (C) 4분의 1
# (D) 2분의 1
# 생성된 답변: (A) 8분의 1.
# 예상 답: A, 실제 답: D
#
# 질문 핵심 추출: 교육과목의 종류와 학점을 정하는 사람은 학장입니다.
# 질문 6: QUESTION6) 교육과목의 종류와 학점을 정하는 사람은?
# (A) 총장
# (B) 학장
# (C) 이사장
# (D) 부총장
# 생성된 답변: (A) 총장
# 예상 답: A, 실제 답: A
#
# 질문 핵심 추출: 전일허가가 가능한 기간은 매 학년도초입니다.
# 질문 7: QUESTION7) 전과 허가가 가능한 기간은?
# (A) 매 학년도초
# (B) 매 학년도말
# (C) 매 년초
# (D) 매 년말
# 생성된 답변: (A) 매 학년도초
# 예상 답: A, 실제 답: B
#
# 질문 핵심 추출: 이화여자대학교의 교육 이념은 기독교 정신과 학문 연구에 기반을 두고 있습니다.
# 답변이 N/A로 표시됨: 다시 확인 중...
# 질문 8: QUESTION8) 이화여자대학교의 교육 이념은 무엇을 기반으로 하고 있습니까?
# (A) 국가 경쟁력 강화
# (B) 기독교 정신과 학문 연구
# (C) 첨단 기술 개발
# (D) 글로벌 경제 협력
# (E) 정부 정책 수립
# 생성된 답변: 정답은 (B) 기독교 정신과 학문 연구입니다. 이화여자대학교는 한국의 대표적인 여성 교육 기관으로, 기독교 정신을 바탕으로 여성 인재 양성을 위해 설립되었습니다. 대학의 교육 이념은 '진학과 인격 계발'을 통해 여성들이 사회에서 중요한 역할을 할 수 있도록 교육하는 것입니다.
# 예상 답: B, 실제 답: B
#
# 질문 핵심 추출: 이화여자대학교 학칙에 따르면 출산 및 육아로 인한 휴학 허용 기간은 최대 3년입니다.
# 질문 9: QUESTION9) 이화여자대학교 학칙에 따르면 출산 및 육아로 인한 휴학 허용 기간은 최대 몇 년입니까?
# (A) 1년
# (B) 2년
# (C) 3년
# (D) 4년
# (E) 5년
# 생성된 답변: (B) 2년
# 예상 답: B, 실제 답: B
#
# 질문 핵심 추출: 이화여자대학교의 졸업 요건 중 영어 관련 기준은 영어 논문을 제출하는 것입니다.
# 질문 10: QUESTION10) 이화여자대학교의 졸업 요건 중 영어 관련 기준은 다음 중 무엇입니까?
# (A) 영어 강의를 최소 10학점 이상 이수
# (B) 영어 인증시험 점수를 제출
# (C) 영어 강의를 이수
# (D) 영어 논문을 제출
# (E) 영어 자격증을 취득
# 생성된 답변: (C) 영어 강의를 이수
# 예상 답: C, 실제 답: C
#
# 질문 핵심 추출: The primary purpose of contract law
# 질문 11: QUESTION11) What is the primary purpose of contract law?
# (A) To regulate public criminal behavior
# (B) To enforce promises made between private parties
# (C) To protect intellectual property rights
# (D) To settle disputes between governments
# (E) To allocate state resources
#
#
# 생성된 답변: (B) To enforce promises made between private parties
# 예상 답: B, 실제 답: B
#
# 질문 핵심 추출: A primary purpose of administrative law
# 질문 12: QUESTION12) Which of the following is a primary purpose of administrative law?
# (A) Regulating private agreements between citizens
# (B) Punishing international crimes
# (C) Enforcing criminal law in states
# (D) Managing disputes between private corporations
# (E) Providing rules for the operation of government agencies
# (F) Determining constitutional rights
# (G) Resolving disputes over intellectual property
# (H) Governing family relations
# (I) Imposing tariffs on imports
# (J) Developing principles for international arbitration
#
# 생성된 답변: (E) Providing rules for the operation of government agencies
# 예상 답: E, 실제 답: J
#
# 질문 핵심 추출: which of the following Enlightenment philosophes designed a system of checks and balances for government to avoid abuses of power
# 질문 13: QUESTION13) Which of the following Enlightenment philosophes designed a system of checks and balances for government to avoid abuses of power?
# (A) Thomas Hobbes
# (B) Jean Jacques Rousseau
# (C) Baron Montesquieu
# (D) Voltaire
# (E) Denis Diderot
# (F) Immanuel Kant
# (G) David Hume
# (H) Mary Wollstonecraft
# (I) Adam Smith
# (J) John Locke
# 생성된 답변: (C) Baron Montesquieu
# 예상 답: C, 실제 답: E
#
# 질문 핵심 추출: Which theory is primarily associated with the concept of operant conditioning?
# 질문 14: QUESTION14) Which theory is primarily associated with the concept of operant conditioning?
# (A) Freud's Psychoanalytic Theory
# (B) Maslow's Hierarchy of Needs
# (C) Piaget's Cognitive Development Theory
# (D) Skinner's Behavioral Theory
# (E) Jung's Archetypal Theory
# (F) Bandura's Social Learning Theory
# (G) Watson's Classical Conditioning Theory
# (H) Pavlov's Dog Experiment
# (I) Erikson's Psychosocial Development Theory
# (J) Kohlberg's Moral Development Theory
# 생성된 답변: (D) Skinner's Behavioral Theory
# 예상 답: D, 실제 답: D
#
# 질문 핵심 추출: primary goal of corporate strategy
# 질문 15: QUESTION15) Which of the following is the primary goal of corporate strategy?
# (A) Managing daily operations
# (B) Developing a marketing campaign
# (C) Achieving long-term competitive advantage
# (D) Establishing supply chain logistics
# (E) Enhancing employee satisfaction
# (F) Conducting market research
# (G) Diversifying customer demographics
# (H) Preparing financial reports
# (I) Creating innovative technology
# (J) Reducing environmental impact
# 생성된 답변: (C) Achieving long-term competitive advantage
# 예상 답: C, 실제 답: C
#
# 질문 핵심 추출: Who is best known for the phrase "Cogito, ergo sum"
# 답변이 N/A로 표시됨: 다시 확인 중...
# 질문 16: QUESTION16) Who is best known for the phrase "Cogito, ergo sum" (I think, therefore I am)?
# (A) Aristotle
# (B) René Descartes
# (C) Immanuel Kant
# (D) Jean-Paul Sartre
# (E) Friedrich Nietzsche
# (F) Søren Kierkegaard
# (G) Thomas Hobbes
# (H) John Locke
# (I) Plato
# (J) Baruch Spinoza
# 생성된 답변: The philosopher best known for the phrase "Cogito, ergo sum" (I think, therefore I am) is René Descartes. So, the correct option is (B) René Descartes.
# 예상 답: B, 실제 답: B
#
# 질문 핵심 추출: Marshall Plan's primary purpose after World War II
# 질문 17: QUESTION17) What was the primary purpose of the Marshall Plan after World War II?
# (A) Rebuilding European economies
# (B) Establishing the United Nations
# (C) Dividing Germany into occupation zones
# (D) Supporting the League of Nations
# (E) Creating the European Union
# (F) Promoting Soviet-American diplomacy
# (G) Ending the Korean War
# (H) Preventing nuclear proliferation
# (I) Forming NATO
# (J) Resolving territorial disputes in Asia
# 생성된 답변: (A) Rebuilding European economies
# 예상 답: A, 실제 답: A
#
# 질문 핵심 추출: Maslow's Hierarchy of Needs identifies the most basic human need
# 질문 18: QUESTION18) What does Maslow's Hierarchy of Needs identify as the most basic human need?
# (A) Self-actualization
# (B) Esteem needs
# (C) Social belonging
# (D) Safety needs
# (E) Physiological needs
# 생성된 답변: (E) Physiological needs
# 예상 답: E, 실제 답: E
#
# 질문 핵심 추출: Assessing internal and external factors affecting a business
# 질문 19: QUESTION19) What is the primary focus of a SWOT analysis in business strategy?
# (A) Evaluating customer satisfaction
# (B) Analyzing financial performance
# (C) Assessing internal and external factors affecting a business
# (D) Identifying product development opportunities
# (E) Determining legal risks
# 생성된 답변: Answer: (C) Assessing internal and external factors affecting a business
# 예상 답: C, 실제 답: C
#
# 질문 핵심 추출: The main cause of World War I
# 질문 20: QUESTION20) What was the main cause of World War I?
# (A) The rise of fascism in Europe
# (B) The assassination of Archduke Franz Ferdinand
# (C) The German invasion of Poland
# (D) The Treaty of Versailles
# (E) The Great Depression
# 생성된 답변: (B) The assassination of Archduke Franz Ferdinand
# 예상 답: B, 실제 답: B
#
# 총 20개의 질문 중 13개 맞춤. 정확도: 65.00%

# %% [markdown]
# STEP 5. 평가

# %%
# main 코드

# %%
# STEP 5. 평가
accuracy = correct / len(prompts) * 100
print(f"acc: {accuracy:.2f}%")
# Out:
# acc: 65.00%
